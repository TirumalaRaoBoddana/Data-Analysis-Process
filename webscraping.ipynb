# %% [markdown]
# # Scraping netflix series data from otten Tomatoes

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Get request to the required url

# %%
url="https://editorial.rottentomatoes.com/guide/best-netflix-shows-and-movies-to-binge-watch-now/"
response=requests.get(url)
print(response.status_code)
# Out:
# 200

# %% [markdown]
# ## creating a soup object

# %%
soup=BeautifulSoup(response.content)

# %%
def getSeriesNames(obj):
    """this function is used to get the netflix series name.it takes one parameter that is the div that contains the information about the pparticular series"""
    return obj.find("h2").find("a").text
def getPoster(obj):
    """
    this function is used to get the poster source of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    return obj.find("img",class_="article_poster")["src"]
def getReleaseYear(obj):
    """
    this function is used to get the release year of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    return obj.find("h2").find("span").text.strip(")(")
def getRatings(obj):
    """
    this function is used to get the ratings of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    return obj.find("span",class_="tMeterScore").text.strip("%")
def getSynopsis(obj):
    """
    this function is used to get the synopsis of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    syn=obj.find("div",class_="synopsis").text[9:]
    syn=syn[0:len(syn)-6]
    return syn
def getCast(obj):
    """
    this function is used to get the cast of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    cast=obj.find("div",class_="cast").find_all("a")
    name=""
    for j in cast:
        name+=j.text+","
    return name.strip(",")
def getDirector(obj):
    """
    this function is used to get the director of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    director=""
    try:
        a=obj.find("div",class_="director").find_all("a")
        for j in a:
            director+=j.text+","
        return director.strip(",")
    except:
        return np.nan

# %%
series_name=[]
posters=[]
release_years=[]
synopsis=[]
ratings=[]
casts=[]
directors=[]
network=[]
genre=[]
language=[]
release_date=[]
def getMoreDetails(obj):
    """
    this function is used to get the more details of the netflix series
    it takes one parameter that is the div that contains the information about the particular series.
    """
    global network
    global genre
    global language
    global release_date
    link=obj.find("h2").find("a")["href"]
    response=requests.get("https:"+link)
    if(response.status_code==200):
        data=BeautifulSoup(response.content)
        for category in data.find_all("div", class_="category-wrap"):
            key = category.find("dt").get_text(strip=True)  # Extract the key (dt content
            value = category.find("dd").get_text("", strip=True) # Extract the value (dd content)
            if(key=="Network"):
                network.append(value)
            elif(key=="Genre"):
                genre.append(value)
            elif(key=="Original Language"):
                language.append(value)
            elif(key=="Release Date"):
                release_date.append(value)
            else:
                continue
    else:
        network.append(np.nan)
        genre.append(np.nan)
        language.append(np.nan)
        release_date.append(np.nan)
    return [network,genre,language,release_date]
#getting all the div tags with class countdown-item that contains the details about the netflix series
# here i is the div that contains the information about the particular series
netflix_series_list=soup.find_all("div",class_="countdown-item")
for i in netflix_series_list:
    series_name.append(getSeriesNames(i))
    posters.append(getPoster(i))
    release_years.append(getReleaseYear(i))
    synopsis.append(getSynopsis(i))
    ratings.append(getRatings(i))
    casts.append(getCast(i))
    directors.append(getDirector(i))
    getMoreDetails(i)

# %% [markdown]
# **Creating a dictionary with the scaped data**

# %%
series_data={"SeriesName":series_name,
             "Poster":posters,
             "ReleaseYear":release_years,
             "Synopsis":synopsis,
             "Rating":ratings,
             "Cast":casts,
             "Director":directors,
             "Network":network,
             "Genre":genre,
             "Language":language,
             "ReleaseDate":release_date,
}
print(len(series_name))
print(len(posters))
print(len(release_years))
print(len(synopsis))
print(len(ratings))
print(len(casts))
print(len(directors))
print(len(network))
print(len(genre))
print(len(language))
print(len(release_date))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %% [markdown]
# **converting the dictionary into the dataframe**

# %%
netflix_series_data=pd.DataFrame(series_data)

# %% [markdown]
# **Exporting the dataframe to csv file**

# %%
netflix_series_data.to_csv("netflix_series_data.csv")
print("successfull")
# Out:
# successfull

# %% [markdown]
# **Web Scraping Financial News Using Python**

# %% [markdown]
# **Importing the libraries**

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **Making get request and creating the soup object**

# %%
url = "https://www.businesstoday.in/latest/economy"
response = requests.get(url)

# %% [markdown]
# **Creating a soup object**

# %%
soup=BeautifulSoup(response.content)
news=soup.find("div",class_="section-listing-LHS")
news_data=news.find_all("div",class_="widget-listing")
links=[]
posters=[]
updated=[]
titles=[]
descriptions=[]
for i in news_data:
  links.append(i.find("div",class_="widget-listing-thumb").find("a")["href"])
  posters.append(i.find("div",class_="widget-listing-thumb").find("a").find("img")["data-src"])
  updated.append(i.find("div",class_="widget-listing-content-section").find("span").text[10:])
  titles.append(i.find("div",class_="widget-listing-content-section").find("h2").find("a").text)
  descriptions.append(i.find("div",class_="widget-listing-content-section").find("p").text)

# %% [markdown]
# **creating a dictionary using the data**

# %%
news={
    "Links":links,
    "Posters":posters,
    "Updated":updated,
    "Titles":titles,
    "Descriptions":descriptions
}

# %% [markdown]
# **creating a dataframe using the dictionary**

# %%
df=pd.DataFrame(news)
df
# Out:
#                                                 Links  \
# 0   https://www.businesstoday.in/latest/economy/st...
# 1   https://www.businesstoday.in/latest/economy/st...
# 2   https://www.businesstoday.in/latest/economy/st...
# 3   https://www.businesstoday.in/latest/economy/st...
# 4   https://www.businesstoday.in/latest/economy/st...
# 5   https://www.businesstoday.in/latest/economy/st...
# 6   https://www.businesstoday.in/personal-finance/...
# 7   https://www.businesstoday.in/latest/economy/st...
# 8   https://www.businesstoday.in/latest/economy/st...
# 9   https://www.businesstoday.in/latest/economy/st...
# 10  https://www.businesstoday.in/india/story/cabin...
# 11  https://www.businesstoday.in/india-at-100/stor...
# 12  https://www.businesstoday.in/latest/economy/st...
# 13  https://www.businesstoday.in/latest/economy/st...
# 14  https://www.businesstoday.in/latest/economy/st...
# 15  https://www.businesstoday.in/latest/economy/st...
# 16  https://www.businesstoday.in/latest/economy/st...
# 17  https://www.businesstoday.in/latest/economy/st...
# 18  https://www.businesstoday.in/latest/economy/st...
# 19  https://www.businesstoday.in/latest/economy/st...
# 20  https://www.businesstoday.in/latest/economy/st...
#
#                                               Posters       Updated  \
# 0   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 18, 2024
# 1   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 16, 2024
# 2   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 14, 2024
# 3   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 13, 2024
# 4   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 13, 2024
# 5   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 13, 2024
# 6   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 12, 2024
# 7   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 12, 2024
# 8   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 12, 2024
# 9   https://akm-img-a-in.tosshub.com/businesstoday...  Aug 10, 2024
# 10  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 09, 2024
# 11  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 09, 2024
# 12  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 08, 2024
# 13  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 08, 2024
# 14  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 08, 2024
# 15  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 08, 2024
# 16  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 08, 2024
# 17  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 07, 2024
# 18  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 07, 2024
# 19  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 07, 2024
# 20  https://akm-img-a-in.tosshub.com/businesstoday...  Aug 07, 2024
#
#                                                Titles  \
# 0   FPIs turn net sellers; sell shares worth Rs 21...
# 1   ‘Did much better than expected’: IMF’s Gita Go...
# 2   Wholesale inflation eases to 2.04% in July as ...
# 3   ‘Need more homegrown firms to list’: Nithin Ka...
# 4   Indian Railways cancels Rs 30,000-crore tender...
# 5   CPI inflation at a 5-yr low: SBI warns about b...
# 6   RBI mandates full emergency refunds for NBFC d...
# 7   CPI inflation at 59-month low but food price p...
# 8   Ministry of Corporate Affairs sets up a dedica...
# 9   Bangladesh update: Garment, Knitted sector is ...
# 10  Cabinet sanctions 8 new line projects for Rail...
# 11  Road to Viksit Bharat: Business Today's webina...
# 12  RBI rate action and stance change unlikely bef...
# 13  RBI raises tax payment limit through UPI from ...
# 14  RBI MPC 2024: Inflation pegged at 4.5% for FY2...
# 15  RBI monetary policy: Gov Shaktikanta Das proje...
# 16  RBI keeps powder dry, repo rate remains unchan...
# 17  RBI MPC Meet: Analysing key macro changes in d...
# 18  Realtors cheer govt’s LTCG tax amendment; to l...
# 19  BIMSTEC nations, startups, and businesses must...
# 20  BIMSTEC trade push: Security General pledges t...
#
#                                          Descriptions
# 0   From August 1 to 17, FPIs withdrew a net amoun...
# 1   "India's growth did much better than we expect...
# 2   The annual rate of inflation for Primary Artic...
# 3   Ola Electric, Unicommerce, FirstCry IPOs: Cong...
# 4   The tender panel found that the company’s bidd...
# 5   CPI inflation for July: The SBI Ecowrap predic...
# 6   For non-emergency premature withdrawals within...
# 7   Month-on-month vegetable inflation rises, anal...
# 8   It has also begun discussions with industry re...
# 9   Bangladesh's textile industry is a crucial com...
# 10  The 8 projects will cover 14 districts in seve...
# 11  This insightful discussion sets the stage for ...
# 12  The central bank decided for the ninth consecu...
# 13  Additionally, the clearing cycle for cheques w...
# 14   The RBI boss further said that inflation in I...
# 15  RBI monetary policy announcements: Gov Shaktik...
# 16  Global markets have been roiled in recent week...
# 17  RBI MPC Meet: The Monetary Policy Committee (M...
# 18  The country’s real estate players and industry...
# 19  Highlighting some potential areas of collabora...
# 20  To expedite trade facilitation, Indra Mani Pan...

# %% [markdown]
# **Scraping Top Rated Indian Movies from IMDB**

# %%
#importing the important libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# defining the url and headers
url="https://www.imdb.com/india/top-rated-indian-movies/"
headers = {"User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36","Accept-Language": "en-US,en;q=0.5"}

# %%
response=requests.get(url,headers=headers)
if(response.status_code==200):
  soup=BeautifulSoup(response.content)
else:
  print("something went wrong")

# %%
movies_list=soup.find_all("li",class_="ipc-metadata-list__item ipc-metadata-list__item--inline ipc-metadata-list-item--link")
posters=[]
names=[]
ratings=[]
directors=[]
for movie in movies_list:
  posters.append(movie.find("img",class_="ipc-image")["src"])
  extra=len(movie.find("span",class_="sc-551fcf62-5 jdAoeV").text)
  names.append(movie.find("span",class_="sc-551fcf62-4 fuEsMb").text[extra:])
  ratings.append(movie.find("span",class_="ipc-rating-star--rating").text)
  link=movie.find("a",class_="ipc-metadata-list-item__icon-link")["href"]
  response=requests.get("https://imdb.com"+link,headers=headers)
  if(response.status_code==200):
    obj=BeautifulSoup(response.content)
    directors.append(obj.find("a",class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link").text)
  else:
    directors.append(np.nan)
# Out:
# ['Vidhu Vinod Chopra',
#  'Hrishikesh Mukherjee',
#  'Mani Ratnam',
#  'Nithilan Saminathan',
#  'Satyajit Ray',
#  'Sundar C.',
#  'Mari Selvaraj',
#  'Rajkumar Hirani',
#  'Rojin Thomas',
#  'Fazil',
#  'Anurag Kashyap',
#  'Madhavan',
#  'Madhu C. Narayanan',
#  'Kiranraj K',
#  'Sibi Malayil',
#  'Venkatesh Maha',
#  'Aamir Khan',
#  'Sathyan Anthikad',
#  'Kiran Rao',
#  'Nitesh Tiwari',
#  'Gowtam Tinnanuri',
#  'Sudha Kongara',
#  'C. Prem Kumar',
#  'Mahesh Manjrekar',
#  'Vetrimaaran',
#  'Jeethu Joseph',
#  'Lokesh Kanagaraj',
#  'Kadiri Venkata Reddy',
#  'Sathyan Anthikad',
#  'Bharathan',
#  'Vetrimaaran',
#  'T.J. Gnanavel',
#  'Mani Ratnam',
#  'Hanu Raghavapudi',
#  'Jeethu Joseph',
#  'S. Shankar',
#  'Kundan Shah',
#  'Dibakar Banerjee',
#  'Satyajit Ray',
#  'Pa. Ranjith',
#  'Vijay K. Bhaskar',
#  'Vetrimaaran',
#  'Mohan Raja',
#  'Satyajit Ray',
#  'Ram Gopal Varma',
#  'Anjali Menon',
#  'Hrishikesh Mukherjee',
#  'Alphonse Puthren',
#  'Swaroop Rsj',
#  'I.V. Sasi',
#  'Nishikant Kamat',
#  'Anurag Kashyap',
#  'Ram Kumar',
#  'Rakeysh Omprakash Mehra',
#  'Vijay Anand',
#  'Shoojit Sircar',
#  'Nag Ashwin',
#  'Ram',
#  'Priyadarshan',
#  'Zoya Akhtar',
#  'Mani Ratnam',
#  'Thiagarajan Kumararaja',
#  'Sriram Raghavan',
#  'S. Shankar',
#  'Hansal Mehta',
#  'Mani Ratnam',
#  'Priyadarshan',
#  'Guru Dutt',
#  'Rajkumar Hirani',
#  'Nagraj Manjule',
#  'Ashutosh Gowariker',
#  'Bhadran',
#  'Nitesh Tiwari',
#  'Rahi Anil Barve',
#  'Jeethu Joseph',
#  'Gayatri',
#  'Chidambaram',
#  'Tigmanshu Dhulia',
#  'Madonne Ashwin',
#  'Mansoor Khan',
#  'Shimit Amin',
#  'Sanjay Leela Bhansali',
#  'Arun Prabhu Purushothaman',
#  'Thiagarajan Kumararaja',
#  'Rajkumar Hirani',
#  'K. Selvaraghavan',
#  'Ashutosh Gowariker',
#  'Dijo Jose Antony',
#  'Lokesh Kanagaraj',
#  'John Mathew Matthan',
#  'Karthik Subbaraj',
#  'Meghna Gulzar',
#  'Gulzar',
#  'Abhishek Pathak',
#  'M. Manikandan',
#  'Ramesh Sippy',
#  'Nalan Kumarasamy',
#  'Anurag Basu',
#  'Aditya Dhar',
#  'Kamal Haasan',
#  'Vikramaditya Motwane',
#  'Rajkumar Santoshi',
#  'Karthick Naren',
#  'Anubhav Sinha',
#  'Umesh Shukla',
#  'Dileesh Pothan',
#  'Jude Anthany Joseph',
#  'Garth Davis',
#  'Anwar Rasheed',
#  'H. Vinoth',
#  'Vikas Bahl',
#  'Sujoy Ghosh',
#  'Neeraj Ghaywan',
#  'Suresh Krishna',
#  'Rajkumar Hirani',
#  'Bala',
#  'Nagesh Kukunoor',
#  'Rakeysh Omprakash Mehra',
#  'Farhan Akhtar',
#  'Ashwiny Iyer Tiwari',
#  'Satyajit Ray',
#  'Neeraj Pandey',
#  'S.S. Rajamouli',
#  'Kabir Khan',
#  'Mani Ratnam',
#  'Mani Ratnam',
#  'Aniruddha Roy Chowdhury',
#  'Bommarillu Baskar',
#  'Hrishikesh Mukherjee',
#  'Vishal Bhardwaj',
#  'Mani Ratnam',
#  'T. Hariharan',
#  'Jayprad Desai',
#  'Ajay Bahl',
#  'S. Shankar',
#  'Vetrimaaran',
#  'K.S. Ravikumar',
#  'Pawan Kumar',
#  'K. Asif',
#  'Aditya Chopra',
#  'Vishal Bhardwaj',
#  'Jeo Baby',
#  'Magizh Thirumeni',
#  'Neeraj Pandey',
#  'Gautham Vasudev Menon',
#  'S.U. Arun Kumar',
#  'Anurag Kashyap',
#  'Vishnuvardhan',
#  'Vishal Bhardwaj',
#  'Tharun Bhascker Dhaassyam',
#  'Sukumar',
#  'Rajkumar Santoshi',
#  'Shouryuv',
#  'Mahesh Manjrekar',
#  'Jyoti Swaroop',
#  'Vetrimaaran',
#  'Prashanth Neel',
#  'Balaji Tharaneetharan',
#  'Apoorv Singh Karki',
#  'Ram Gopal Varma',
#  'Yash Chopra',
#  'Lokesh Kanagaraj',
#  'Trivikram Srinivas',
#  'Anurag Kashyap',
#  'Venkat Prabhu',
#  'Martin Prakkat',
#  'Amit Ravindernath Sharma',
#  'Hemanth M. Rao',
#  'Venkat Ramji',
#  'Ravikanth Perepu',
#  'Zoya Akhtar',
#  'Sachy',
#  'Rishab Shetty',
#  'Srijit Mukherji',
#  'Rakshit Shetty',
#  'Martin Prakkat',
#  'Anand Gandhi',
#  'Imtiaz Ali',
#  'Dileesh Pothan',
#  'A.L. Vijay',
#  'Ranjith',
#  'Karan Johar',
#  'J.P. Dutta',
#  'Mahesh Narayanan',
#  'Anurag Kashyap',
#  'Gautham Ramachandran',
#  'Anurag Kashyap',
#  'Raj B. Shetty',
#  'Ketan Mehta',
#  'Mathur Goswami',
#  'Nikkhil Advani',
#  'Radha Krishna Jagarlamudi',
#  'Vignesh Raja',
#  'Mira Nair',
#  'Gautham Vasudev Menon',
#  'Karthik Subbaraj',
#  'Satyajit Ray',
#  'R. Balki',
#  'Vineeth Sreenivasan',
#  'Rajesh Pillai',
#  'Rishab Shetty',
#  'Saket Chaudhary',
#  'Ratheesh Balakrishnan Poduval',
#  'Prashanth Neel',
#  'Karthik Subbaraj',
#  'Rajat Kapoor',
#  'Sashi Kiran Tikka',
#  'Vikas Bahl',
#  'Sriram Raghavan',
#  'Gauri Shinde',
#  'Nagesh Kukunoor',
#  'M. Padmakumar',
#  'Midhun Manuel Thomas',
#  'Kamal Haasan',
#  'Mari Selvaraj',
#  'S.S. Rajamouli',
#  'Jeethu Joseph',
#  'Pradeep Ranganathan',
#  'Neeraj Pandey',
#  'Mahesh Narayanan',
#  'Farhan Akhtar',
#  'Raj Kapoor',
#  'Ritesh Batra',
#  'Prakash Jha',
#  'Sandeep Reddy Vanga',
#  'Gautham Vasudev Menon',
#  'Blessy',
#  'Gautham Vasudev Menon',
#  'Shimit Amin',
#  'Raja Menon',
#  'Vamshi Paidipally',
#  'Amit Ravindernath Sharma',
#  'Rosshan Andrrews',
#  'Chakri Toleti',
#  'Puri Jagannadh',
#  'A.R. Murugadoss',
#  'Amole Gupte',
#  'Sekhar Kammula',
#  'S. Shankar',
#  'Yash Chopra',
#  'Vivek Agnihotri',
#  'Gunasekhar',
#  'Vikram K. Kumar',
#  'Shoojit Sircar',
#  'Lijo Jose Pellissery',
#  'Shekhar Kapur',
#  'Sudhir Mishra',
#  'Dharani',
#  'Abhinav Sunder Nayak',
#  'Sekhar Kammula']

# %%
movies_dict=dict({
     "poster":posters,
     "MovieName":names,
     "Rating":ratings,
     "Director":directors
 })
movies_df=pd.DataFrame(movies_dict)
movies_df.to_csv("top_rated_indian_movies.csv")

# %% [markdown]
# **Scraping book details from books.toscrape.com**

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **Creating a soup object**

# %%
posters=[]
names=[]
ratings=[]
prices=[]
availability=[]
for j in range(1,51,1):
  url = "https://books.toscrape.com/catalogue/page-{}.html".format(j)
  headers = {
      "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36",
      "Accept-Language": "en-US,en;q=0.5",
  }
  response = requests.get(url, headers=headers)
  soup=BeautifulSoup(response.content)
  #getting all the list items where each item is a book
  data=soup.find("section").find_all("div")[1].find("ol",class_="row").find_all("li")
  for i in data:
    posters.append(i.find("article").find("div",class_="image_container").find("img")["src"])
    names.append(i.find("article").find("h3").get_text())
    ratings.append(i.find("article").find("p").get("class")[1])
    prices.append(i.find("article").find("div",class_="product_price").find('p').text)
    availability.append(i.find("article").find("div",class_="product_price").find("p",class_="instock availability").get_text().strip())

# %%
#converting the list of lists into dictionary
book_dict={
    "poster":posters,
    "name":names,
    "rating":ratings,
    "price":prices,
    "availability":availability
}

# %%
#converting it into datadframe
import pandas as pd
book_df=pd.DataFrame(book_dict)
book_df
# Out:
#                                                 poster  \
# 0    ../media/cache/2c/da/2cdad67c44b002e7ead0cc356...
# 1    ../media/cache/26/0c/260c6ae16bce31c8f8c95dadd...
# 2    ../media/cache/3e/ef/3eef99c9d9adef34639f51066...
# 3    ../media/cache/32/51/3251cf3a3412f53f339e42cac...
# 4    ../media/cache/be/a5/bea5697f2534a2f86a3ef27b5...
# ..                                                 ...
# 995  ../media/cache/96/ee/96ee77d71a31b7694dac6855f...
# 996  ../media/cache/09/7c/097cb5ecc6fb3fbe1690cf0cb...
# 997  ../media/cache/1b/5f/1b5ff86f3c75e51e24c573d3f...
# 998  ../media/cache/2b/41/2b4161c5b72a4ae386b644682...
# 999  ../media/cache/d7/0f/d70f7edd92705c45a82118c3f...
#
#                                  name rating   price availability
# 0                  A Light in the ...  Three  £51.77     In stock
# 1                  Tipping the Velvet    One  £53.74     In stock
# 2                          Soumission    One  £50.10     In stock
# 3                       Sharp Objects   Four  £47.82     In stock
# 4        Sapiens: A Brief History ...   Five  £54.23     In stock
# ..                                ...    ...     ...          ...
# 995  Alice in Wonderland (Alice's ...    One  £55.53     In stock
# 996    Ajin: Demi-Human, Volume 1 ...   Four  £57.06     In stock
# 997         A Spy's Devotion (The ...   Five  £16.97     In stock
# 998           1st to Die (Women's ...    One  £53.98     In stock
# 999           1,000 Places to See ...   Five  £26.08     In stock
#
# [1000 rows x 5 columns]

# %%
#exporting the dataframe to csv file
book_df.to_csv("books.csv")

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np

# Initialize lists to store data
links = []
posters = []
authors = []
dates = []
ratings = []
prices = []
names = []
delivery_dates = []

# URL for Amazon search
for page in range(1,101,1):
  url = 'https://www.amazon.com/s?k=best+machine+learning+books&qid=1724405523&ref=sr_pg_{}'.format(page)

  # Headers to mimic a real browser
  custom_headers = {
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
      'Accept-Language': 'da, en-gb, en',
      'Accept-Encoding': 'gzip, deflate, br',
      'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
      'Referer': 'https://www.google.com/'
  }

  # Sending the request
  response = requests.get(url, headers=custom_headers)
  if response.status_code == 200:
    # Creating the soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    res_data = soup.find_all("div", class_="s-result-item")
    for item in res_data:
        # Extract links
        a_tag = item.find("a", class_="a-link-normal")
        if a_tag:
          links.append("https://www.amazon.com" + a_tag["href"])
        else:
          links.append(np.nan)
        # Extract posters
        img_tag = item.find("img", class_="s-image")
        if img_tag and img_tag.has_attr("src"):
          posters.append(img_tag["src"])
        else:
          posters.append(np.nan)
        # Extract names
        name_tag = item.find("span", class_="a-size-medium")
        if name_tag:
          names.append(name_tag.text.strip())
        else:
          names.append(np.nan)
        # Extract authors
        author_div = item.find("div", class_="a-row a-size-base a-color-secondary")
        if author_div:
          author_links = author_div.find_all("a")
          authors.append(", ".join([author.text for author in author_links]))
        else:
          authors.append(np.nan)
        # Extract dates
        date_tag = item.find("span", class_="a-size-base a-color-secondary a-text-normal")
        if date_tag:
          dates.append(date_tag.text.strip())
        else:
          dates.append(np.nan)
        # Extract ratings
        rating_tag = item.find("span", class_="a-icon-alt")
        if rating_tag:
          ratings.append(rating_tag.text.split()[0])  # Extract the numeric rating
        else:
          ratings.append(np.nan)
        # Extract prices
        price_whole = item.find("span", class_="a-price-whole")
        price_fraction = item.find("span", class_="a-price-fraction")
        if price_whole and price_fraction:
          prices.append(price_whole.text + price_fraction.text)
        else:
          prices.append(np.nan)
        # Extract delivery dates
        delivery_tag = item.find("span", class_="a-color-base a-text-bold")
        if delivery_tag:
          delivery_dates.append(delivery_tag.text.strip())
        else:
          delivery_dates.append(np.nan)
print("yes")
# Out:
# yes

# %%
#converting lists into the dictionary
product_details={
    "links":links,
    "posters":posters,
    "names":names,
    "authors":authors,
    "date_of_release":dates,
    "ratings":ratings,
    "prices":prices,
}
print("yes")
# Out:
# yes

# %%
#converting to dataframe
import pandas as pd
df=pd.DataFrame(product_details)

# %%
df.dropna(inplace=True)

# %%
# printing the dataframe
df.reset_index(drop=True,inplace=True)
df.to_csv("machine_learning_books.csv")
print("yes")
# Out:
# yes
